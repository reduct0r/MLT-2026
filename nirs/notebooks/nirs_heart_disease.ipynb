# %% [markdown]
# # НИРС: Прогнозирование сердечно-сосудистых заболеваний
#
# Типовое исследование. Набор данных: **Heart Disease (Cleveland)**, UCI.
#
# Полный воспроизводимый пайплайн также в `scripts/run_pipeline.py`.

# %% [markdown]
# ## 1. Выбор набора данных и постановка задачи
#
# Бинарная классификация: наличие ССЗ (1) / отсутствие (0).

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from src.data_loader import load_heart_disease, FEATURE_LABELS

df = load_heart_disease(ROOT / 'data')
df.head()

# %% [markdown]
# ## 2. Разведочный анализ данных

# %%
df.info()
df.describe()

# %%
df['target_label'].value_counts().plot(kind='bar', title='Распределение классов')
plt.show()

# %% [markdown]
# ## 3–11. Обучение моделей, метрики, GridSearch
#
# Запустите скрипт для генерации всех графиков и таблиц метрик:

# %%
# %run ../scripts/run_pipeline.py

# %%
import pandas as pd
metrics = pd.read_csv(ROOT / 'reports/figures/metrics_table.csv')
metrics[metrics['metric']=='roc_auc'].pivot(index='alg', columns='stage', values='value')

# %% [markdown]
# ## 12. Веб-приложение Streamlit
#
# ```bash
# streamlit run app/streamlit_app.py
# ```
